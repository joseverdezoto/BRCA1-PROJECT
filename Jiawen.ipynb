# %%
import numpy as np
import pandas as pd

# %%
pd.read_excel('gene_expression_table4.xlsx')
# Out:
#                                              Accession           Symbol  \
# 0                                               U34343   13-kDa protein
# 1                                               U15552  82-kDa  protein
# 2                                               X58528            ABCD3
# 3                                               X82207           ACTR1B
# 4                                               X13839            ACTSA
# 5                                               S83513          ADCYAP1
# 6                                               L07261             ADD1
# 7                                               Z68280             ADD1
# 8                                               U37122             ADD3
# 9                                               D14878              ADM
# 10                                              X66503             ADSS
# 11                                              U56418           AGPAT2
# ...

# %%
np.load('gene_expression_table4.xlsx')
